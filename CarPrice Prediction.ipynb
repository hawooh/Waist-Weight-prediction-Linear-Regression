# %%
import os
os.chdir("C:\\Users\\OLAOYE OLUWATOBILOBA\\Documents")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("carprice prediction.csv")
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data[70:73]
# Out:
#     car_ID  symboling                  CarName fueltype aspiration doornumber  \
# 70      71         -1            buick skyhawk   diesel      turbo       four
# 71      72         -1  buick opel isuzu deluxe      gas        std       four
# 72      73          3            buick skylark      gas        std        two
#
#         carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 70        sedan        rwd          front      115.6  ...         183
# 71        sedan        rwd          front      115.6  ...         234
# 72  convertible        rwd          front       96.6  ...         234
#
#     fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# 70         idi       3.58    3.64             21.5        123     4350
# 71        mpfi       3.46    3.10              8.3        155     4750
# 72        mpfi       3.46    3.10              8.3        155     4750
#
#    citympg  highwaympg    price
# 70      22          25  31600.0
# ...

# %%
 data.loc[:,["car_ID", "CarName"]]
# Out:
#      car_ID                   CarName
# 0         1        alfa-romero giulia
# 1         2       alfa-romero stelvio
# 2         3  alfa-romero Quadrifoglio
# 3         4               audi 100 ls
# 4         5                audi 100ls
# ..      ...                       ...
# 200     201           volvo 145e (sw)
# 201     202               volvo 144ea
# 202     203               volvo 244dl
# 203     204                 volvo 246
# 204     205               volvo 264gl
#
# [205 rows x 2 columns]

# %%
data["CarName"]>="50"
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 200    True
# 201    True
# 202    True
# 203    True
# 204    True
# Name: CarName, Length: 205, dtype: bool

# %%
data[data["CarName"]>="50"]
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
fifty=data[data["CarName"]>="50"]

# %%
fifty.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data.shape
# Out:
# (205, 26)

# %%
from sklearn.linear_model  import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()

# %%
data["CarName"]=LE.fit_transform(data["CarName"])
data["fueltype"]=LE.fit_transform(data["fueltype"])
data["aspiration"]=LE.fit_transform(data["aspiration"])

data["drivewheel"]=LE.fit_transform(data["drivewheel"])
data["enginelocation"]=LE.fit_transform(data["enginelocation"])
data["fuelsystem"]=LE.fit_transform(data["fuelsystem"])
data["doornumber"]=LE.fit_transform(data["doornumber"])
data["carbody"]=LE.fit_transform(data["carbody"])



data["price"]=LE.fit_transform(data["price"])

# %%
X=data.drop("price",axis=1)
y=data["price"]

# %%
print(data["CarName"].dtypes)
# Out:
# int32

# %%
data.tail()
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 200     201         -1      139         1           0           0        3
# 201     202         -1      138         1           1           0        3
# 202     203         -1      140         1           0           0        3
# 203     204         -1      142         0           1           0        3
# 204     205         -1      143         1           1           0        3
#
#      drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200           2               0      109.1  ...         141           5
# 201           2               0      109.1  ...         141           5
# 202           2               0      109.1  ...         173           5
# 203           2               0      109.1  ...         145           3
# 204           2               0      109.1  ...         141           5
#
#      boreratio  stroke compressionratio horsepower  peakrpm  citympg  \
# ...

# %%
from sklearn.model_selection   import train_test_split
X_train, X_test,y_train,y_test=train_test_split(X,y, test_size=0.2, random_state=0 )

# %%
print(data["fueltype"].describe())
# Out:
# count    205.000000
# mean       0.902439
# std        0.297446
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: fueltype, dtype: float64

# %%
# Exploring the types of Datatypes in the Dataset
list(set(data.dtypes.tolist()))
# Out:
# [dtype('float64'), dtype('O'), dtype('int32'), dtype('int64')]

# %%
#give me all the Numerical data we have
data_num=data.select_dtypes(include= ["float64", "int32","int64"])
data_num.head()
# Out:
#    car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0       1          3        2         1           0           1        0
# 1       2          3        3         1           0           1        0
# 2       3          1        1         1           0           1        2
# 3       4          2        4         1           0           0        3
# 4       5          2        5         1           0           0        3
#
#    drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0           2               0       88.6  ...         130           5
# 1           2               0       88.6  ...         130           5
# 2           2               0       94.5  ...         152           5
# 3           1               0       99.8  ...         109           5
# 4           0               0       99.4  ...         136           5
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
#taking a look at the Distribution of our Data Using Histogram
data_num.hist(figsize=(16, 20), bins=50, xlabelsize=8,ylabelsize=8)
# Out:
# array([[<AxesSubplot:title={'center':'car_ID'}>,
#         <AxesSubplot:title={'center':'symboling'}>,
#         <AxesSubplot:title={'center':'CarName'}>,
#         <AxesSubplot:title={'center':'fueltype'}>,
#         <AxesSubplot:title={'center':'aspiration'}>],
#        [<AxesSubplot:title={'center':'doornumber'}>,
#         <AxesSubplot:title={'center':'carbody'}>,
#         <AxesSubplot:title={'center':'drivewheel'}>,
#         <AxesSubplot:title={'center':'enginelocation'}>,
#         <AxesSubplot:title={'center':'wheelbase'}>],
#        [<AxesSubplot:title={'center':'carlength'}>,
#         <AxesSubplot:title={'center':'carwidth'}>,
#         <AxesSubplot:title={'center':'carheight'}>,
#         <AxesSubplot:title={'center':'curbweight'}>,
#         <AxesSubplot:title={'center':'enginesize'}>],
#        [<AxesSubplot:title={'center':'fuelsystem'}>,
#         <AxesSubplot:title={'center':'boreratio'}>,
#         <AxesSubplot:title={'center':'stroke'}>,
# ...

# %%
#checking the Correlated Values with Price

data_num_corr=data_num.corr()["price"][:-1]
Car_Price_list=data_num_corr[abs(data_num_corr)> 0.5].sort_values(ascending=False)
print("there is {} correlated valueswith Price:\n{}".format(len(Car_Price_list),Car_Price_list))
# Out:
# there is 11 correlated valueswith Price:
# curbweight    0.882935
# horsepower    0.793904
# carwidth      0.791989
# carlength     0.790965
# enginesize    0.753165
# fuelsystem    0.707890
# wheelbase     0.637745
# boreratio     0.626323
# drivewheel    0.600088
# citympg      -0.792104
# highwaympg   -0.792362
# Name: price, dtype: float64

# %%
# Creating a Visualizing of the relation of a particular Columns with the first five(5) Columns
for i in range(0,len(data_num.columns), 5):
    sns.pairplot(data=data_num,
                x_vars=data_num.columns[i:i+5],
                y_vars=["price"])

# %%
Ling=LinearRegression()

# %%
print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 4         5          2        5         1           0           0        3
# 71       72         -1       20         1           0           0        3
# 134     135          3      103         1           0           1        2
# 145     146          0      109         1           1           0        3
# 122     123          1       91         1           0           0        3
# ..      ...        ...      ...       ...         ...         ...      ...
# 67       68         -1       19         0           1           0        3
# 192     193          0      135         0           1           0        3
# 117     118          0       88         1           1           0        3
# 47       48          0       49         1           0           0        3
# 172     173          2      124         1           0           1        0
#
# ...

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (164, 25)
# (41, 25)
# (164,)
# (41,)

# %%
data.head()
# Out:
#    car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0       1          3        2         1           0           1        0
# 1       2          3        3         1           0           1        0
# 2       3          1        1         1           0           1        2
# 3       4          2        4         1           0           0        3
# 4       5          2        5         1           0           0        3
#
#    drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0           2               0       88.6  ...         130           5
# 1           2               0       88.6  ...         130           5
# 2           2               0       94.5  ...         152           5
# 3           1               0       99.8  ...         109           5
# 4           0               0       99.4  ...         136           5
#
#    boreratio  stroke compressionratio horsepower  peakrpm  citympg  \
# ...

# %%
import re

# %%
Ling.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-d47d53886e10> in <module>
# ----> 1 Ling.fit(X_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...

# %%
print(round(accuracy_score(y_test,y_predict)*100,2))
